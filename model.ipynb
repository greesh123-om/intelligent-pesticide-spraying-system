# %% [markdown]
# <a href="https://colab.research.google.com/github/greesh123-om/intelligent-pesticide-spraying-system/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.4/107.7 GB disk)
#
# OS                     Linux-6.6.97+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.11
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   39.4/107.7 GB
# CPU                    Intel Xeon CPU @ 2.20GHz
# CPU count              2
# GPU                    None
# GPU count              None
# CUDA                   None
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.12.0.88>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.2>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.2>=1.4.1
# torch                  ✅ 2.8.0+cu126>=1.8.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dbDLhRWWN7ZAvYB2BYaI")
project = rf.workspace("firedet-l1qmb").project("optimal-pest-control-kscau")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 103.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to optimal-pest-control-2 in yolov8:: 100%|██████████| 1796/1796 [00:00<00:00, 7797.64it/s]
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/optimal-pest-control-2/data.yaml epochs=25 imgsz=416 batch=8
# Out:
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls /content/runs/detect/train/weights/
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/runs/detect/train/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2341044011.py in <cell line: 0>()
#       2
#       3 # Load your trained model
# ----> 4 model = YOLO('/content/runs/detect/train/weights/best.pt')
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      81         else:
#      82             # Continue with default YOLO initialization
# ---> 83             super().__init__(model=model, task=task, verbose=verbose)
#      84             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      85                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     151             self._new(model, task=task, verbose=verbose)
#     152         else:
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Choose a test image from your computer
# Out:
#      <input type="file" id="files-d4158e44-5f34-4070-9e23-759ca52d5902" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4158e44-5f34-4070-9e23-759ca52d5902">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]

# %%
results = model.predict(source=image_path, save=True, conf=0.25)
# Out:
# image 1/1 /content/rice-leaf-folder-larvae-one-260nw-1701682756.webp: 416x320 1 insects, 96.5ms
# Speed: 2.5ms preprocess, 96.5ms inference, 10.7ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to /content/runs/detect/predict

# %%
from IPython.display import Image
import glob

# Get the predicted image
output_image = glob.glob('/content/runs/detect/predict/*.jpg')[0]

# Show it
Image(filename=output_image)

# %%
# !ls /content/runs/detect/train/weights/
# Out:
# best.pt  last.pt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/
# !cp /content/runs/detect/train/weights/last.pt /content/drive/MyDrive/

# %%
pip install ultralytics opencv-python

# %%
from google.colab import files
uploaded = files.upload()  # Choose a test image from your computer
# Out:
#      <input type="file" id="files-542e19f4-8147-4b07-8e39-be4a0ea62c5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-542e19f4-8147-4b07-8e39-be4a0ea62c5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]

# %%
results = model.predict(source=image_path, save=True, conf=0.25)
# Out:
# image 1/1 /content/cochliobolus.jpg: 288x416 4 colour changes, 2 insectss, 83.7ms
# Speed: 2.3ms preprocess, 83.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 416)
# Results saved to /content/runs/detect/predict
